# %%
import pandas as pd
billboard = pd.read_csv("billboard.csv")
billboard
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  x4th.week  \
# ...

# %%
billboard.shape
# Out:
# (317, 81)

# %%
billboard.columns
# Out:
# Index(['artiste', 'track', 'genre', 'date.entered', 'date.peaked', 'x1st.week',
#        'x2nd.week', 'x3rd.week', 'x4th.week', 'x5th.week', 'x6th.week',
#        'x7th.week', 'x8th.week', 'x9th.week', 'x10th.week', 'x11th.week',
#        'x12th.week', 'x13th.week', 'x14th.week', 'x15th.week', 'x16th.week',
#        'x17th.week', 'x18th.week', 'x19th.week', 'x20th.week', 'x21st.week',
#        'x22nd.week', 'x23rd.week', 'x24th.week', 'x25th.week', 'x26th.week',
#        'x27th.week', 'x28th.week', 'x29th.week', 'x30th.week', 'x31st.week',
#        'x32nd.week', 'x33rd.week', 'x34th.week', 'x35th.week', 'x36th.week',
#        'x37th.week', 'x38th.week', 'x39th.week', 'x40th.week', 'x41st.week',
#        'x42nd.week', 'x43rd.week', 'x44th.week', 'x45th.week', 'x46th.week',
#        'x47th.week', 'x48th.week', 'x49th.week', 'x50th.week', 'x51st.week',
#        'x52nd.week', 'x53rd.week', 'x54th.week', 'x55th.week', 'x56th.week',
# ...

# %%
billboard = billboard.dropna(thresh=9)

# %%
billboard.shape
# Out:
# (300, 81)

# %%
new_billboard = pd.melt(billboard, id_vars=['artiste', 'track', 'genre', 'date.entered', 'date.peaked',],var_name='week',value_name='rank')
new_billboard
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 22795                Trina                              Pull Over   Rap
# 22796              Lil' Mo                                  Ta Da   Rap
# 22797              A*Teens                          Dancing Queen   Pop
# 22798        Sheist, Shade                       Where I Wanna Be   Rap
# 22799          Smith, Will                            Freakin' It   Rap
#
#       date.entered date.peaked        week  rank
# 0       2000-09-23  2000-11-18   x1st.week  78.0
# ...

# %%
new_billboard.dtypes
# Out:
# artiste          object
# track            object
# genre            object
# date.entered     object
# date.peaked      object
# week             object
# rank            float64
# dtype: object

# %%
new_billboard['week'] = new_billboard['week'].str.extract('(\d+)').astype(int)

# %%
new_billboard
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 22795                Trina                              Pull Over   Rap
# 22796              Lil' Mo                                  Ta Da   Rap
# 22797              A*Teens                          Dancing Queen   Pop
# 22798        Sheist, Shade                       Where I Wanna Be   Rap
# 22799          Smith, Will                            Freakin' It   Rap
#
#       date.entered date.peaked  week  rank
# 0       2000-09-23  2000-11-18     1  78.0
# ...

# %%
new_billboard.dtypes
# Out:
# artiste          object
# track            object
# genre            object
# date.entered     object
# date.peaked      object
# week              int64
# rank            float64
# dtype: object

# %%
new_billboard['date.entered'] = pd.to_datetime(new_billboard['date.entered'])
new_billboard['date.peaked'] = pd.to_datetime(new_billboard['date.peaked'])
new_billboard
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 22795                Trina                              Pull Over   Rap
# 22796              Lil' Mo                                  Ta Da   Rap
# 22797              A*Teens                          Dancing Queen   Pop
# 22798        Sheist, Shade                       Where I Wanna Be   Rap
# 22799          Smith, Will                            Freakin' It   Rap
#
#       date.entered date.peaked  week  rank
# 0       2000-09-23  2000-11-18     1  78.0
# ...

# %%
new_billboard['entered_to_peak']=new_billboard['date.peaked']-new_billboard['date.entered']

# %%
new_billboard
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 22795                Trina                              Pull Over   Rap
# 22796              Lil' Mo                                  Ta Da   Rap
# 22797              A*Teens                          Dancing Queen   Pop
# 22798        Sheist, Shade                       Where I Wanna Be   Rap
# 22799          Smith, Will                            Freakin' It   Rap
#
#       date.entered date.peaked  week  rank entered_to_peak
# ...

# %%
new_billboard.dtypes
# Out:
# artiste                     object
# track                       object
# genre                       object
# date.entered        datetime64[ns]
# date.peaked         datetime64[ns]
# week                         int64
# rank                       float64
# entered_to_peak    timedelta64[ns]
# dtype: object

# %%
new_billboard['entered_to_peak'] =  new_billboard['entered_to_peak'].dt.days

# %%
new_billboard.dtypes
# Out:
# artiste                    object
# track                      object
# genre                      object
# date.entered       datetime64[ns]
# date.peaked        datetime64[ns]
# week                        int64
# rank                      float64
# entered_to_peak             int64
# dtype: object

# %%
new_billboard[new_billboard['genre'] == 'Rock']
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 22782       Carter, Torrey                              Take That  Rock
# 22785          Limp Bizkit                            Re-Arranged  Rock
# 22787                Tamar             If You Don't Wanna Love Me  Rock
# 22792         Price, Kelly                     Love Sets You Free  Rock
# 22793             En Vogue                                 Riddle  Rock
#
#       date.entered date.peaked  week  rank  entered_to_peak
# ...

# %%
new_billboard = new_billboard.sort_values(['rank'])

# %%
new_billboard
# Out:
#                    artiste                                  track genre  \
# 3904   Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# 4800       Destiny's Child               Independent Women Part I  Rock
# 5100       Destiny's Child               Independent Women Part I  Rock
# 3914               Aaliyah                              Try Again  Rock
# 3910                N'Sync                       It's Gonna Be Me  Rock
# ...                    ...                                    ...   ...
# 22795                Trina                              Pull Over   Rap
# 22796              Lil' Mo                                  Ta Da   Rap
# 22797              A*Teens                          Dancing Queen   Pop
# 22798        Sheist, Shade                       Where I Wanna Be   Rap
# 22799          Smith, Will                            Freakin' It   Rap
#
#       date.entered date.peaked  week  rank  entered_to_peak
# ...

# %%
new_billboard[new_billboard['entered_to_peak'] == 35]
# Out:
#              artiste                        track genre date.entered  \
# 1503         Madonna                        Music  Rock   2000-08-12
# 2403         Madonna                        Music  Rock   2000-08-12
# 1803         Madonna                        Music  Rock   2000-08-12
# 2103         Madonna                        Music  Rock   2000-08-12
# 3003         Madonna                        Music  Rock   2000-08-12
# ...              ...                          ...   ...          ...
# 22748    Limp Bizkit               N 2 Gether Now  Rock   1999-12-04
# 22760      Metallica                  I Disappear  Rock   2000-05-13
# 22775  Moore, Chante                  Straight Up  Rock   2000-10-28
# 22776        Cam'ron  What Means The World To You   Rap   2000-10-14
# 22796        Lil' Mo                        Ta Da   Rap   2000-08-12
#
#       date.peaked  week  rank  entered_to_peak
# 1503   2000-09-16     6   1.0               35
# ...

# %% [markdown]
# # Ans: Madonna's Music track ranked 1 in Rock after peaking 35days from entering into the competition
